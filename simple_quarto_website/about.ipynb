# %% [markdown]
# # ipsum lorem
# ## ipsum lorem
# ### ipsum lorem

# %%
#| label: load-packages-py
#| echo: fenced
#| code-fold: false
#| eval: false

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
   
x = [2,4,6] 
y = [4,7,1] 
    
plt.plot(x, y) 
    
plt.xlabel('natural') 
plt.ylabel('language processing') 
    
plt.title('Python Plot') 
    
plt.show()

# %% [raw]
# ---
# title: "About"
# ---

# %% [markdown]
# About this site
